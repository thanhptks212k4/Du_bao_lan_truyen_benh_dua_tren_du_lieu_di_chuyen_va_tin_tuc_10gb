# %%
import torch
from torch.utils.data import Dataset, DataLoader

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
# Tạo Dataset và DataLoader
dataset = TimeSeriesDataset(X, y)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import torch.nn as nn
import numpy as np

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))  # (1, max_len, d_model)

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]
class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.layer = nn.TransformerEncoderLayer(d_model, n_heads, d_ff, batch_first=True)

    def forward(self, x):
        return self.layer(x)
class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.layer = nn.TransformerDecoderLayer(d_model, n_heads, d_ff, batch_first=True)

    def forward(self, tgt, memory):
        return self.layer(tgt, memory)

# %%
class InformerClassifier(nn.Module):
    def __init__(self, input_dim, d_model, n_heads, d_ff, n_layers, pred_len, n_classes):
        super().__init__()
        self.pred_len = pred_len

        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_enc = PositionalEncoding(d_model)

        self.encoder_layers = nn.ModuleList([
            EncoderLayer(d_model, n_heads, d_ff) for _ in range(n_layers)
        ])

        self.decoder_input = nn.Parameter(torch.zeros(1, pred_len, d_model))
        self.decoder_layers = nn.ModuleList([
            DecoderLayer(d_model, n_heads, d_ff) for _ in range(n_layers)
        ])

        self.classifier = nn.Linear(d_model, n_classes)

    def forward(self, x):
        # x: (B, seq_len, input_dim)
        x = self.input_proj(x)  # (B, seq_len, d_model)
        x = self.pos_enc(x)

        # Encoder
        for layer in self.encoder_layers:
            x = layer(x)
        memory = x

        # Decoder (dự báo pred_len bước tương lai)
        dec_in = self.decoder_input.repeat(x.size(0), 1, 1)  # (B, pred_len, d_model)
        for layer in self.decoder_layers:
            dec_in = layer(dec_in, memory)

        out = dec_in.mean(dim=1)  # Lấy đặc trưng trung bình của pred_len bước
        return self.classifier(out)  # (B, n_classes)

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
import matplotlib.pyplot as plt
import torch

def train_model(model, train_loader, num_epochs=20, lr=1e-3):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = torch.nn.CrossEntropyLoss()

    acc_list, f1_list, loss_list = [], [], []

    for epoch in range(num_epochs):
        model.train()
        y_true, y_pred = [], []
        total_loss = 0.0

        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            optimizer.zero_grad()
            output = model(batch_x)
            loss = criterion(output, batch_y)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            preds = output.argmax(dim=1)
            y_true.extend(batch_y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

        avg_loss = total_loss / len(train_loader)
        acc = accuracy_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred, average='weighted')

        acc_list.append(acc)
        f1_list.append(f1)
        loss_list.append(avg_loss)

        print(f"Epoch {epoch+1}: Loss={avg_loss:.4f}")

    # In kết quả cuối cùng
    print(f"\nFinal Accuracy: {acc_list[-1]:.4f}")
    print(f"Final F1 Score: {f1_list[-1]:.4f}")
    print("\n=== Classification Report ===")
    print(classification_report(y_true, y_pred, digits=2))

    # Vẽ biểu đồ loss
    plt.figure(figsize=(8, 4))
    plt.plot(loss_list, label='Loss', color='blue')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training Loss per Epoch")
    plt.grid(True)
    plt.legend()
    plt.show()

    return acc_list[-1], f1_list[-1]

# %% [markdown]
# # Swine_Flu

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

file_path = "Swine_Flu.csv"  # <-- thay bằng tên thật trong dataset

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tinthnhphm21022004/datalantruyenbenh",
  file_path,
)

print(df.head())
# Out:
# /tmp/ipykernel_35/305386452.py:8: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                   date        username          to  replies  retweets  \
# 0  2016-01-29 23:44:36  TallaTrialogue         NaN      1.0       0.0
# 1  2016-01-29 23:44:35  TallaTrialogue  LorDempsey      0.0       0.0
# 2  2016-01-29 23:42:24      LorDempsey         NaN      2.0       0.0
# 3  2016-01-29 23:34:20         drayzze  Fab_Mommy_      1.0       2.0
# 4  2016-01-29 23:32:24   DispatchDaily         NaN      0.0       0.0
#
#    favorites                                               text  geo  \
# 0        0.0  .@lordempsey @independent_ie 1976 &amp; 40+ mi...  NaN
# 1        0.0  .@lordempsey @independent_ie 1976 &amp; 40+ mi...  NaN
# 2        0.0  I had flu when pregnant, horrendous.Pregnant w...  NaN
# 3        1.0  @FabMommy29 @dreww07 How do you treat swine fl...  NaN
# 4        0.0  Swine flu alert prompts vaccination call: Medi...  NaN
#
#                       mentions hashtags            id  \
# 0  @LorDempsey @Independent_ie      NaN  6.932182e+17
# 1  @LorDempsey @Independent_ie      NaN  6.932182e+17
# 2              @Independent_ie      NaN  6.932177e+17
# 3                          NaN      NaN  6.932156e+17
# 4                          NaN      NaN  6.932151e+17
#
#                                            permalink
# 0  https://twitter.com/TallaTrialogue/status/6932...
# 1  https://twitter.com/TallaTrialogue/status/6932...
# 2  https://twitter.com/LorDempsey/status/69321766...
# 3  https://twitter.com/drayzze/status/69321563254...
# 4  https://twitter.com/DispatchDaily/status/69321...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.stats import mode

# 1. Parse ngày, bỏ dayfirst nếu dữ liệu là YYYY-MM-DD
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df['day'] = df['date'].dt.date
df['year'] = df['date'].dt.year

# 2. Tính số bài đăng mỗi ngày
daily_counts = df.groupby('day').size().reset_index(name='count')
daily_counts['year'] = pd.to_datetime(daily_counts['day']).dt.year

# 3. Tính tỷ lệ mỗi năm
yearly_total = daily_counts.groupby('year')['count'].transform('sum')
daily_counts['ratio'] = daily_counts['count'] / yearly_total

# 4. Trong hàm phân lớp, loại bỏ cột 'year' để tránh nhóm áp dụng trên cột nhóm
def classify_per_year(df_year):
    # Không drop cột 'year' nữa
    q1 = df_year['ratio'].quantile(1/3)
    q2 = df_year['ratio'].quantile(2/3)

    def label_row(r):
        if r <= q1:
            return 0
        elif r <= q2:
            return 1
        else:
            return 2

    df_year = df_year.copy()
    df_year['label'] = df_year['ratio'].apply(label_row)
    return df_year

# Áp dụng, loại bỏ cột 'year' trước khi apply để tránh bị lặp cột
daily_counts_no_year = daily_counts.drop(columns=['year'])

daily_counts_labeled = (
    daily_counts_no_year
    .groupby(daily_counts['year'], group_keys=False)  # groupby dựa trên cột year gốc bên ngoài dataframe tạm
    .apply(classify_per_year)
    .reset_index(drop=True)
)

# Thêm lại cột 'year' từ cột 'day' cho chắc chắn
daily_counts_labeled['year'] = pd.to_datetime(daily_counts_labeled['day']).dt.year

# Sắp xếp lại, gán lại dataframe chính
daily_counts = daily_counts_labeled.sort_values('day').reset_index(drop=True)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
daily_counts['count_scaled'] = scaler.fit_transform(daily_counts[['count']])

# 8. Tạo chuỗi thời gian
from scipy.stats import mode

window_size = 30
horizon = 7

X, y = [], []
for i in range(len(daily_counts) - window_size - horizon):
    X.append(daily_counts['count_scaled'].values[i:i+window_size])
    future_labels = daily_counts['label'].values[i+window_size:i+window_size+horizon]

    mode_result = mode(future_labels, keepdims=True)
    if mode_result.mode.size > 0:
        y.append(mode_result.mode[0])
    else:
        y.append(future_labels[0])  # fallback

X = np.array(X)[..., np.newaxis]
y = np.array(y)

# %%
daily_counts
# Out:
#              day  count     ratio  label  year  count_scaled
# 0     2007-10-31      3  0.600000      2  2007     -0.355846
# 1     2007-11-20      1  0.200000      0  2007     -0.356616
# 2     2007-12-07      1  0.200000      0  2007     -0.356616
# 3     2008-01-15      1  0.055556      0  2008     -0.356616
# 4     2008-02-12      1  0.055556      0  2008     -0.356616
# ...          ...    ...       ...    ...   ...           ...
# 3756  2020-06-15    329  0.000890      0  2020     -0.230323
# 3757  2020-06-16    440  0.001190      0  2020     -0.187584
# 3758  2020-06-17    429  0.001160      0  2020     -0.191819
# 3759  2020-06-18   3078  0.008326      2  2020      0.828147
# 3760  2020-06-19    630  0.001704      1  2020     -0.114427
#
# [3761 rows x 6 columns]

# %%
model = InformerClassifier(input_dim=1, d_model=64, n_heads=4, d_ff=128, n_layers=2, pred_len=30, n_classes=3)
accuracy, f1 = train_model(model, train_loader, num_epochs=150)
# Out:
# Epoch 1: Loss=1.0922
# Epoch 2: Loss=1.0188
# Epoch 3: Loss=1.0037
# Epoch 4: Loss=0.9847
# Epoch 5: Loss=0.9683
# Epoch 6: Loss=0.9709
# Epoch 7: Loss=0.9595
# Epoch 8: Loss=0.9466
# Epoch 9: Loss=0.9438
# Epoch 10: Loss=0.9379
# Epoch 11: Loss=0.9296
# Epoch 12: Loss=0.9172
# Epoch 13: Loss=0.9127
# Epoch 14: Loss=0.8966
# Epoch 15: Loss=0.8868
# Epoch 16: Loss=0.9039
# Epoch 17: Loss=0.8688
# Epoch 18: Loss=0.8678
# Epoch 19: Loss=0.8652
# Epoch 20: Loss=0.8522
# Epoch 21: Loss=0.8415
# Epoch 22: Loss=0.8417
# Epoch 23: Loss=0.8237
# Epoch 24: Loss=0.8106
# Epoch 25: Loss=0.8217
# Epoch 26: Loss=0.7989
# Epoch 27: Loss=0.7956
# Epoch 28: Loss=0.7838
# Epoch 29: Loss=0.7900
# Epoch 30: Loss=0.7918
# Epoch 31: Loss=0.7900
# Epoch 32: Loss=0.7622
# Epoch 33: Loss=0.7590
# Epoch 34: Loss=0.7543
# Epoch 35: Loss=0.7474
# Epoch 36: Loss=0.7413
# Epoch 37: Loss=0.7500
# Epoch 38: Loss=0.7391
# Epoch 39: Loss=0.7246
# Epoch 40: Loss=0.7195
# Epoch 41: Loss=0.7140
# Epoch 42: Loss=0.7085
# Epoch 43: Loss=0.7069
# Epoch 44: Loss=0.6879
# Epoch 45: Loss=0.7108
# Epoch 46: Loss=0.6937
# Epoch 47: Loss=0.7062
# Epoch 48: Loss=0.7187
# Epoch 49: Loss=0.6901
# Epoch 50: Loss=0.6769
# Epoch 51: Loss=0.6735
# Epoch 52: Loss=0.6654
# Epoch 53: Loss=0.6570
# Epoch 54: Loss=0.6578
# Epoch 55: Loss=0.6546
# Epoch 56: Loss=0.6620
# Epoch 57: Loss=0.6432
# Epoch 58: Loss=0.6733
# Epoch 59: Loss=0.6546
# Epoch 60: Loss=0.6445
# Epoch 61: Loss=0.6336
# Epoch 62: Loss=0.6437
# Epoch 63: Loss=0.6191
# Epoch 64: Loss=0.6266
# Epoch 65: Loss=0.6307
# Epoch 66: Loss=0.6109
# Epoch 67: Loss=0.6184
# Epoch 68: Loss=0.6297
# Epoch 69: Loss=0.6213
# Epoch 70: Loss=0.5949
# Epoch 71: Loss=0.5977
# Epoch 72: Loss=0.5951
# Epoch 73: Loss=0.6112
# Epoch 74: Loss=0.5804
# Epoch 75: Loss=0.5745
# Epoch 76: Loss=0.5987
# Epoch 77: Loss=0.5805
# Epoch 78: Loss=0.5876
# Epoch 79: Loss=0.5810
# Epoch 80: Loss=0.5611
# Epoch 81: Loss=0.5609
# Epoch 82: Loss=0.5706
# Epoch 83: Loss=0.5867
# Epoch 84: Loss=0.5729
# Epoch 85: Loss=0.5362
# Epoch 86: Loss=0.5519
# Epoch 87: Loss=0.5340
# Epoch 88: Loss=0.5570
# Epoch 89: Loss=0.5395
# Epoch 90: Loss=0.5427
# Epoch 91: Loss=0.5107
# Epoch 92: Loss=0.5420
# Epoch 93: Loss=0.5318
# Epoch 94: Loss=0.5366
# Epoch 95: Loss=0.5145
# Epoch 96: Loss=0.5196
# Epoch 97: Loss=0.5347
# Epoch 98: Loss=0.5093
# Epoch 99: Loss=0.5314
# Epoch 100: Loss=0.4889
# Epoch 101: Loss=0.5000
# Epoch 102: Loss=0.5121
# Epoch 103: Loss=0.4934
# Epoch 104: Loss=0.4952
# Epoch 105: Loss=0.5008
# Epoch 106: Loss=0.4949
# Epoch 107: Loss=0.4877
# Epoch 108: Loss=0.4961
# Epoch 109: Loss=0.4915
# Epoch 110: Loss=0.4857
# Epoch 111: Loss=0.4639
# Epoch 112: Loss=0.4885
# Epoch 113: Loss=0.4723
# Epoch 114: Loss=0.4673
# Epoch 115: Loss=0.4640
# Epoch 116: Loss=0.4568
# Epoch 117: Loss=0.4774
# Epoch 118: Loss=0.4556
# Epoch 119: Loss=0.4626
# Epoch 120: Loss=0.4577
# Epoch 121: Loss=0.4445
# Epoch 122: Loss=0.4641
# Epoch 123: Loss=0.4392
# Epoch 124: Loss=0.4328
# Epoch 125: Loss=0.4223
# Epoch 126: Loss=0.4264
# Epoch 127: Loss=0.4212
# Epoch 128: Loss=0.4329
# Epoch 129: Loss=0.4104
# Epoch 130: Loss=0.4168
# Epoch 131: Loss=0.4083
# Epoch 132: Loss=0.4138
# Epoch 133: Loss=0.4041
# Epoch 134: Loss=0.4207
# Epoch 135: Loss=0.3995
# Epoch 136: Loss=0.4078
# Epoch 137: Loss=0.4051
# Epoch 138: Loss=0.3948
# Epoch 139: Loss=0.3847
# Epoch 140: Loss=0.4078
# Epoch 141: Loss=0.3808
# Epoch 142: Loss=0.4001
# Epoch 143: Loss=0.3901
# Epoch 144: Loss=0.4029
# Epoch 145: Loss=0.3741
# Epoch 146: Loss=0.4012
# Epoch 147: Loss=0.3964
# Epoch 148: Loss=0.3744
# Epoch 149: Loss=0.3913
# Epoch 150: Loss=0.3728
#
# Final Accuracy: 0.8432
# Final F1 Score: 0.8431
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1353
#            1       0.80      0.77      0.79      1187
#            2       0.92      0.86      0.89      1184
#
#     accuracy                           0.84      3724
#    macro avg       0.85      0.84      0.84      3724
# weighted avg       0.85      0.84      0.84      3724

# %%
torch.save(model.state_dict(), 'Swine_Flu_model.pt')
print("Model saved to Swine_Flu_model.pt")
# Out:
# Model saved to Swine_Flu_model.pt

# %% [markdown]
# # Ebola

# %%
file_path = "Ebola.csv"  # <-- thay bằng tên thật trong dataset

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tinthnhphm21022004/datalantruyenbenh",
  file_path,
)

print(df.head())
# Out:
# /tmp/ipykernel_35/4186054764.py:3: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                   date        username          to  replies  retweets  \
# 0  2017-12-31 23:57:09    TeActualizas         NaN        0         0
# 1  2017-12-31 23:53:56    amandamoe398         NaN        0         0
# 2  2017-12-31 23:51:28  michael_warren         NaN        0         0
# 3  2017-12-31 23:47:45      CryptYcat7         NaN        0         0
# 4  2017-12-31 23:44:34     VeritasEver  regina1775        1         0
#
#    favorites                                               text  geo mentions  \
# 0          0  Cómo el cambio climático ayudará a predecir vi...  NaN      NaN
# 1          0  New GMO Wheat Contains Hemmorrhagic Fever - Yo...  NaN      NaN
# 2          0  The latest The ASEAN Global Hub! https://paper...  NaN      NaN
# 3          0  State of the world is cancer and Ebola combine...  NaN      NaN
# 4          2  That's absolutely correct! Wild viruses mutate...  NaN      NaN
#
#                      hashtags            id  \
# 0                      #Salud  9.476177e+17
# 1                         NaN  9.476168e+17
# 2  #infectiousdiseases #ebola  9.476162e+17
# 3                         NaN  9.476153e+17
# 4                         NaN  9.476145e+17
#
#                                            permalink
# 0  https://twitter.com/TeActualizas/status/947617...
# 1  https://twitter.com/amandamoe398/status/947616...
# 2  https://twitter.com/michael_warren/status/9476...
# 3  https://twitter.com/CryptYcat7/status/94761529...
# 4  https://twitter.com/VeritasEver/status/9476144...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.stats import mode

# 1. Parse ngày, bỏ dayfirst nếu dữ liệu là YYYY-MM-DD
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df['day'] = df['date'].dt.date
df['year'] = df['date'].dt.year

# 2. Tính số bài đăng mỗi ngày
daily_counts = df.groupby('day').size().reset_index(name='count')
daily_counts['year'] = pd.to_datetime(daily_counts['day']).dt.year

# 3. Tính tỷ lệ mỗi năm
yearly_total = daily_counts.groupby('year')['count'].transform('sum')
daily_counts['ratio'] = daily_counts['count'] / yearly_total

# 4. Trong hàm phân lớp, loại bỏ cột 'year' để tránh nhóm áp dụng trên cột nhóm
def classify_per_year(df_year):
    # Không drop cột 'year' nữa
    q1 = df_year['ratio'].quantile(1/3)
    q2 = df_year['ratio'].quantile(2/3)

    def label_row(r):
        if r <= q1:
            return 0
        elif r <= q2:
            return 1
        else:
            return 2

    df_year = df_year.copy()
    df_year['label'] = df_year['ratio'].apply(label_row)
    return df_year

# Áp dụng, loại bỏ cột 'year' trước khi apply để tránh bị lặp cột
daily_counts_no_year = daily_counts.drop(columns=['year'])

daily_counts_labeled = (
    daily_counts_no_year
    .groupby(daily_counts['year'], group_keys=False)  # groupby dựa trên cột year gốc bên ngoài dataframe tạm
    .apply(classify_per_year)
    .reset_index(drop=True)
)

# Thêm lại cột 'year' từ cột 'day' cho chắc chắn
daily_counts_labeled['year'] = pd.to_datetime(daily_counts_labeled['day']).dt.year

# Sắp xếp lại, gán lại dataframe chính
daily_counts = daily_counts_labeled.sort_values('day').reset_index(drop=True)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
daily_counts['count_scaled'] = scaler.fit_transform(daily_counts[['count']])

# 8. Tạo chuỗi thời gian
from scipy.stats import mode

window_size = 30
horizon = 7

X, y = [], []
for i in range(len(daily_counts) - window_size - horizon):
    X.append(daily_counts['count_scaled'].values[i:i+window_size])
    future_labels = daily_counts['label'].values[i+window_size:i+window_size+horizon]

    mode_result = mode(future_labels, keepdims=True)
    if mode_result.mode.size > 0:
        y.append(mode_result.mode[0])
    else:
        y.append(future_labels[0])  # fallback

X = np.array(X)[..., np.newaxis]
y = np.array(y)

# %%
daily_counts
# Out:
#              day  count     ratio  label  year  count_scaled
# 0     2006-12-25      1  1.000000      0  2006     -0.173516
# 1     2007-02-14      5  0.017921      2  2007     -0.173367
# 2     2007-02-15      1  0.003584      0  2007     -0.173516
# 3     2007-02-23      1  0.003584      0  2007     -0.173516
# 4     2007-03-06      1  0.003584      0  2007     -0.173516
# ...          ...    ...       ...    ...   ...           ...
# 4288  2020-06-15   2803  0.012857      2  2020     -0.069219
# 4289  2020-06-16   3082  0.014137      2  2020     -0.058834
# 4290  2020-06-17   2638  0.012100      2  2020     -0.075360
# 4291  2020-06-18   2492  0.011431      2  2020     -0.080795
# 4292  2020-06-19   1105  0.005069      2  2020     -0.132423
#
# [4293 rows x 6 columns]

# %%
model = InformerClassifier(input_dim=1, d_model=64, n_heads=4, d_ff=128, n_layers=2, pred_len=30, n_classes=3)
accuracy, f1 = train_model(model, train_loader, num_epochs=150)
# Out:
# Epoch 1: Loss=1.0797
# Epoch 2: Loss=1.0159
# Epoch 3: Loss=1.0043
# Epoch 4: Loss=0.9902
# Epoch 5: Loss=0.9794
# Epoch 6: Loss=0.9763
# Epoch 7: Loss=0.9641
# Epoch 8: Loss=0.9667
# Epoch 9: Loss=0.9564
# Epoch 10: Loss=0.9456
# Epoch 11: Loss=0.9389
# Epoch 12: Loss=0.9314
# Epoch 13: Loss=0.9374
# Epoch 14: Loss=0.9270
# Epoch 15: Loss=0.9167
# Epoch 16: Loss=0.9128
# Epoch 17: Loss=0.9041
# Epoch 18: Loss=0.9046
# Epoch 19: Loss=0.8815
# Epoch 20: Loss=0.8764
# Epoch 21: Loss=0.8714
# Epoch 22: Loss=0.8659
# Epoch 23: Loss=0.8546
# Epoch 24: Loss=0.8458
# Epoch 25: Loss=0.8344
# Epoch 26: Loss=0.8320
# Epoch 27: Loss=0.8271
# Epoch 28: Loss=0.8358
# Epoch 29: Loss=0.8267
# Epoch 30: Loss=0.8119
# Epoch 31: Loss=0.7914
# Epoch 32: Loss=0.7996
# Epoch 33: Loss=0.7734
# Epoch 34: Loss=0.7773
# Epoch 35: Loss=0.7651
# Epoch 36: Loss=0.7732
# Epoch 37: Loss=0.7747
# Epoch 38: Loss=0.7447
# Epoch 39: Loss=0.7495
# Epoch 40: Loss=0.7621
# Epoch 41: Loss=0.7461
# Epoch 42: Loss=0.7392
# Epoch 43: Loss=0.7362
# Epoch 44: Loss=0.7480
# Epoch 45: Loss=0.7334
# Epoch 46: Loss=0.7274
# Epoch 47: Loss=0.7166
# Epoch 48: Loss=0.7180
# Epoch 49: Loss=0.7010
# Epoch 50: Loss=0.7136
# Epoch 51: Loss=0.7030
# Epoch 52: Loss=0.7043
# Epoch 53: Loss=0.7184
# Epoch 54: Loss=0.6870
# Epoch 55: Loss=0.6772
# Epoch 56: Loss=0.6864
# Epoch 57: Loss=0.6794
# Epoch 58: Loss=0.6947
# Epoch 59: Loss=0.6864
# Epoch 60: Loss=0.6681
# Epoch 61: Loss=0.6655
# Epoch 62: Loss=0.6646
# Epoch 63: Loss=0.6754
# Epoch 64: Loss=0.6594
# Epoch 65: Loss=0.6366
# Epoch 66: Loss=0.6548
# Epoch 67: Loss=0.6379
# Epoch 68: Loss=0.6484
# Epoch 69: Loss=0.6407
# Epoch 70: Loss=0.6546
# Epoch 71: Loss=0.6530
# Epoch 72: Loss=0.6316
# Epoch 73: Loss=0.6440
# Epoch 74: Loss=0.6418
# Epoch 75: Loss=0.6153
# Epoch 76: Loss=0.6228
# Epoch 77: Loss=0.6296
# Epoch 78: Loss=0.6318
# Epoch 79: Loss=0.6314
# Epoch 80: Loss=0.6178
# Epoch 81: Loss=0.6131
# Epoch 82: Loss=0.6109
# Epoch 83: Loss=0.5996
# Epoch 84: Loss=0.6052
# Epoch 85: Loss=0.6106
# Epoch 86: Loss=0.5911
# Epoch 87: Loss=0.6144
# Epoch 88: Loss=0.5944
# Epoch 89: Loss=0.5990
# Epoch 90: Loss=0.5766
# Epoch 91: Loss=0.5820
# Epoch 92: Loss=0.6070
# Epoch 93: Loss=0.5888
# Epoch 94: Loss=0.5896
# Epoch 95: Loss=0.6180
# Epoch 96: Loss=0.5893
# Epoch 97: Loss=0.5948
# Epoch 98: Loss=0.5750
# Epoch 99: Loss=0.5782
# Epoch 100: Loss=0.5960
# Epoch 101: Loss=0.5625
# Epoch 102: Loss=0.5722
# Epoch 103: Loss=0.5643
# Epoch 104: Loss=0.5710
# Epoch 105: Loss=0.5691
# Epoch 106: Loss=0.5598
# Epoch 107: Loss=0.5861
# Epoch 108: Loss=0.5576
# Epoch 109: Loss=0.5329
# Epoch 110: Loss=0.5544
# Epoch 111: Loss=0.5555
# Epoch 112: Loss=0.5510
# Epoch 113: Loss=0.5527
# Epoch 114: Loss=0.5469
# Epoch 115: Loss=0.5480
# Epoch 116: Loss=0.5455
# Epoch 117: Loss=0.5485
# Epoch 118: Loss=0.5390
# Epoch 119: Loss=0.5266
# Epoch 120: Loss=0.5234
# Epoch 121: Loss=0.5431
# Epoch 122: Loss=0.5234
# Epoch 123: Loss=0.5316
# Epoch 124: Loss=0.5164
# Epoch 125: Loss=0.5410
# Epoch 126: Loss=0.5196
# Epoch 127: Loss=0.5134
# Epoch 128: Loss=0.5343
# Epoch 129: Loss=0.5202
# Epoch 130: Loss=0.5006
# Epoch 131: Loss=0.5119
# Epoch 132: Loss=0.5188
# Epoch 133: Loss=0.5109
# Epoch 134: Loss=0.5360
# Epoch 135: Loss=0.5115
# Epoch 136: Loss=0.5086
# Epoch 137: Loss=0.5091
# Epoch 138: Loss=0.4946
# Epoch 139: Loss=0.5035
# Epoch 140: Loss=0.4898
# Epoch 141: Loss=0.5139
# Epoch 142: Loss=0.4907
# Epoch 143: Loss=0.5160
# Epoch 144: Loss=0.5109
# Epoch 145: Loss=0.4975
# Epoch 146: Loss=0.4913
# Epoch 147: Loss=0.4934
# Epoch 148: Loss=0.5039
# Epoch 149: Loss=0.4815
# Epoch 150: Loss=0.4693
#
# Final Accuracy: 0.7887
# Final F1 Score: 0.7871
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80      1353
#            1       0.76      0.65      0.70      1187
#            2       0.89      0.82      0.86      1184
#
#     accuracy                           0.79      3724
#    macro avg       0.80      0.78      0.79      3724
# weighted avg       0.79      0.79      0.79      3724

# %%
torch.save(model.state_dict(), 'Ebola_model.pt')
print("Model saved to Ebola_model.pt")
# Out:
# Model saved to Ebola_model.pt

# %% [markdown]
# # Cholera

# %%
file_path = "Cholera.csv"  # <-- thay bằng tên thật trong dataset

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tinthnhphm21022004/datalantruyenbenh",
  file_path,
)

print(df.head())
# Out:
# /tmp/ipykernel_35/3021847062.py:3: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                   date         username   to  replies  retweets  favorites  \
# 0  2017-07-02 23:59:50      demactivist  NaN        0         0          0
# 1  2017-07-02 23:59:19    AzizChristine  NaN        0         0          0
# 2  2017-07-02 23:58:48      WashiMartin  NaN        0         0          0
# 3  2017-07-02 23:58:23  emergencyglobal  NaN        0         0          0
# 4  2017-07-02 23:58:22  emergencyglobal  NaN        0         0          0
#
#                                                 text  geo mentions hashtags  \
# 0  To Stop Cholera &amp; Famine, Stop Refueling S...  NaN  @MoveOn      NaN
# 1  Aid workers warn of 'devastating' cholera outb...  NaN      NaN      NaN
# 2  To Stop Cholera &amp; Famine, Stop Refueling S...  NaN  @MoveOn      NaN
# 3  Yemen: Yemen: Amanat Al Asimah Governorate - C...  NaN      NaN      NaN
# 4  Yemen: Yemen: Al Mahwit Governorate - Cholera ...  NaN      NaN      NaN
#
#                    id                                          permalink
# 0  881663738897739776  https://twitter.com/demactivist/status/8816637...
# 1  881663606802305024  https://twitter.com/AzizChristine/status/88166...
# 2  881663479014404096  https://twitter.com/WashiMartin/status/8816634...
# 3  881663373431250944  https://twitter.com/emergencyglobal/status/881...
# 4  881663369220173824  https://twitter.com/emergencyglobal/status/881...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.stats import mode

# 1. Parse ngày, bỏ dayfirst nếu dữ liệu là YYYY-MM-DD
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df['day'] = df['date'].dt.date
df['year'] = df['date'].dt.year

# 2. Tính số bài đăng mỗi ngày
daily_counts = df.groupby('day').size().reset_index(name='count')
daily_counts['year'] = pd.to_datetime(daily_counts['day']).dt.year

# 3. Tính tỷ lệ mỗi năm
yearly_total = daily_counts.groupby('year')['count'].transform('sum')
daily_counts['ratio'] = daily_counts['count'] / yearly_total

# 4. Trong hàm phân lớp, loại bỏ cột 'year' để tránh nhóm áp dụng trên cột nhóm
def classify_per_year(df_year):
    # Không drop cột 'year' nữa
    q1 = df_year['ratio'].quantile(1/3)
    q2 = df_year['ratio'].quantile(2/3)

    def label_row(r):
        if r <= q1:
            return 0
        elif r <= q2:
            return 1
        else:
            return 2

    df_year = df_year.copy()
    df_year['label'] = df_year['ratio'].apply(label_row)
    return df_year

# Áp dụng, loại bỏ cột 'year' trước khi apply để tránh bị lặp cột
daily_counts_no_year = daily_counts.drop(columns=['year'])

daily_counts_labeled = (
    daily_counts_no_year
    .groupby(daily_counts['year'], group_keys=False)  # groupby dựa trên cột year gốc bên ngoài dataframe tạm
    .apply(classify_per_year)
    .reset_index(drop=True)
)

# Thêm lại cột 'year' từ cột 'day' cho chắc chắn
daily_counts_labeled['year'] = pd.to_datetime(daily_counts_labeled['day']).dt.year

# Sắp xếp lại, gán lại dataframe chính
daily_counts = daily_counts_labeled.sort_values('day').reset_index(drop=True)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
daily_counts['count_scaled'] = scaler.fit_transform(daily_counts[['count']])

# 8. Tạo chuỗi thời gian
from scipy.stats import mode

window_size = 30
horizon = 7

X, y = [], []
for i in range(len(daily_counts) - window_size - horizon):
    X.append(daily_counts['count_scaled'].values[i:i+window_size])
    future_labels = daily_counts['label'].values[i+window_size:i+window_size+horizon]

    mode_result = mode(future_labels, keepdims=True)
    if mode_result.mode.size > 0:
        y.append(mode_result.mode[0])
    else:
        y.append(future_labels[0])  # fallback

X = np.array(X)[..., np.newaxis]
y = np.array(y)

# %%
daily_counts
# Out:
#              day  count     ratio  label  year  count_scaled
# 0     2007-01-19      1  0.003534      0  2007     -0.853706
# 1     2007-02-25      1  0.003534      0  2007     -0.853706
# 2     2007-03-13      1  0.003534      0  2007     -0.853706
# 3     2007-04-12      2  0.007067      1  2007     -0.851997
# 4     2007-04-26      1  0.003534      0  2007     -0.853706
# ...          ...    ...       ...    ...   ...           ...
# 4634  2020-06-15   1387  0.007360      2  2020      1.515050
# 4635  2020-06-16   1548  0.008214      2  2020      1.790208
# 4636  2020-06-17   1412  0.007493      2  2020      1.557776
# 4637  2020-06-18   1204  0.006389      1  2020      1.202292
# 4638  2020-06-19    973  0.005163      1  2020      0.807499
#
# [4639 rows x 6 columns]

# %%
model = InformerClassifier(input_dim=1, d_model=64, n_heads=4, d_ff=128, n_layers=2, pred_len=30, n_classes=3)
accuracy, f1 = train_model(model, train_loader, num_epochs=150)
# Out:
# Epoch 1: Loss=1.1013
# Epoch 2: Loss=1.0181
# Epoch 3: Loss=1.0057
# Epoch 4: Loss=0.9970
# Epoch 5: Loss=0.9826
# Epoch 6: Loss=0.9740
# Epoch 7: Loss=0.9602
# Epoch 8: Loss=0.9497
# Epoch 9: Loss=0.9508
# Epoch 10: Loss=0.9652
# Epoch 11: Loss=0.9309
# Epoch 12: Loss=0.9310
# Epoch 13: Loss=0.9259
# Epoch 14: Loss=0.9074
# Epoch 15: Loss=0.9010
# Epoch 16: Loss=0.8870
# Epoch 17: Loss=0.8975
# Epoch 18: Loss=0.8978
# Epoch 19: Loss=0.8799
# Epoch 20: Loss=0.8786
# Epoch 21: Loss=0.8751
# Epoch 22: Loss=0.8702
# Epoch 23: Loss=0.8548
# Epoch 24: Loss=0.8576
# Epoch 25: Loss=0.8495
# Epoch 26: Loss=0.8388
# Epoch 27: Loss=0.8344
# Epoch 28: Loss=0.8334
# Epoch 29: Loss=0.8215
# Epoch 30: Loss=0.8127
# Epoch 31: Loss=0.8108
# Epoch 32: Loss=0.8091
# Epoch 33: Loss=0.8064
# Epoch 34: Loss=0.8056
# Epoch 35: Loss=0.7919
# Epoch 36: Loss=0.7835
# Epoch 37: Loss=0.7922
# Epoch 38: Loss=0.7845
# Epoch 39: Loss=0.7767
# Epoch 40: Loss=0.7739
# Epoch 41: Loss=0.7639
# Epoch 42: Loss=0.7766
# Epoch 43: Loss=0.7891
# Epoch 44: Loss=0.7666
# Epoch 45: Loss=0.7458
# Epoch 46: Loss=0.7477
# Epoch 47: Loss=0.7282
# Epoch 48: Loss=0.7439
# Epoch 49: Loss=0.7290
# Epoch 50: Loss=0.7306
# Epoch 51: Loss=0.7411
# Epoch 52: Loss=0.7384
# Epoch 53: Loss=0.7170
# Epoch 54: Loss=0.7197
# Epoch 55: Loss=0.7205
# Epoch 56: Loss=0.7068
# Epoch 57: Loss=0.7093
# Epoch 58: Loss=0.7004
# Epoch 59: Loss=0.7127
# Epoch 60: Loss=0.6954
# Epoch 61: Loss=0.6997
# Epoch 62: Loss=0.6973
# Epoch 63: Loss=0.6776
# Epoch 64: Loss=0.6743
# Epoch 65: Loss=0.6751
# Epoch 66: Loss=0.6909
# Epoch 67: Loss=0.6803
# Epoch 68: Loss=0.6667
# Epoch 69: Loss=0.6741
# Epoch 70: Loss=0.6642
# Epoch 71: Loss=0.6712
# Epoch 72: Loss=0.6644
# Epoch 73: Loss=0.6567
# Epoch 74: Loss=0.6730
# Epoch 75: Loss=0.6645
# Epoch 76: Loss=0.6542
# Epoch 77: Loss=0.6603
# Epoch 78: Loss=0.6633
# Epoch 79: Loss=0.6358
# Epoch 80: Loss=0.6434
# Epoch 81: Loss=0.6310
# Epoch 82: Loss=0.6511
# Epoch 83: Loss=0.6230
# Epoch 84: Loss=0.6344
# Epoch 85: Loss=0.6372
# Epoch 86: Loss=0.6386
# Epoch 87: Loss=0.6383
# Epoch 88: Loss=0.6391
# Epoch 89: Loss=0.6234
# Epoch 90: Loss=0.6334
# Epoch 91: Loss=0.6553
# Epoch 92: Loss=0.6233
# Epoch 93: Loss=0.6040
# Epoch 94: Loss=0.6270
# Epoch 95: Loss=0.6475
# Epoch 96: Loss=0.6120
# Epoch 97: Loss=0.6204
# Epoch 98: Loss=0.6125
# Epoch 99: Loss=0.5989
# Epoch 100: Loss=0.6032
# Epoch 101: Loss=0.6095
# Epoch 102: Loss=0.6008
# Epoch 103: Loss=0.6018
# Epoch 104: Loss=0.6196
# Epoch 105: Loss=0.5937
# Epoch 106: Loss=0.5961
# Epoch 107: Loss=0.6113
# Epoch 108: Loss=0.5899
# Epoch 109: Loss=0.6063
# Epoch 110: Loss=0.6028
# Epoch 111: Loss=0.6066
# Epoch 112: Loss=0.6077
# Epoch 113: Loss=0.6098
# Epoch 114: Loss=0.6089
# Epoch 115: Loss=0.6066
# Epoch 116: Loss=0.5989
# Epoch 117: Loss=0.5849
# Epoch 118: Loss=0.5860
# Epoch 119: Loss=0.5754
# Epoch 120: Loss=0.5614
# Epoch 121: Loss=0.5714
# Epoch 122: Loss=0.5779
# Epoch 123: Loss=0.5846
# Epoch 124: Loss=0.5632
# Epoch 125: Loss=0.5619
# Epoch 126: Loss=0.5681
# Epoch 127: Loss=0.5540
# Epoch 128: Loss=0.5586
# Epoch 129: Loss=0.5562
# Epoch 130: Loss=0.5754
# Epoch 131: Loss=0.5434
# Epoch 132: Loss=0.5537
# Epoch 133: Loss=0.5722
# Epoch 134: Loss=0.5559
# Epoch 135: Loss=0.5563
# Epoch 136: Loss=0.5541
# Epoch 137: Loss=0.5599
# Epoch 138: Loss=0.5495
# Epoch 139: Loss=0.5311
# Epoch 140: Loss=0.5450
# Epoch 141: Loss=0.5335
# Epoch 142: Loss=0.5322
# Epoch 143: Loss=0.5559
# Epoch 144: Loss=0.5526
# Epoch 145: Loss=0.5403
# Epoch 146: Loss=0.5278
# Epoch 147: Loss=0.5290
# Epoch 148: Loss=0.5414
# Epoch 149: Loss=0.5382
# Epoch 150: Loss=0.5406
#
# Final Accuracy: 0.7564
# Final F1 Score: 0.7546
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77      1353
#            1       0.72      0.60      0.65      1187
#            2       0.88      0.80      0.84      1184
#
#     accuracy                           0.76      3724
#    macro avg       0.77      0.75      0.75      3724
# weighted avg       0.76      0.76      0.75      3724

# %%
torch.save(model.state_dict(), 'Cholera_model.pt')
print("Model saved to Cholera_model.pt")
# Out:
# Model saved to Cholera_model.pt

# %% [markdown]
# # Mers

# %%
file_path = "2012_MERS.csv"  # <-- thay bằng tên thật trong dataset

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tinthnhphm21022004/datalantruyenbenh",
  file_path,
)

print(df.head())
# Out:
# /tmp/ipykernel_35/1870307657.py:3: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                   date         username              to  replies  retweets  \
# 0  2018-09-30 00:30:03         CHMMNews             NaN        0         0
# 1  2020-03-31 23:47:14          chiIIum             NaN        4        88
# 2  2020-03-31 23:41:35  english_longbow     BarackObama        0         0
# 3  2020-03-31 23:37:59           paanfo  nicolerycroft1        1         1
# 4  2020-03-31 23:33:14   Real_Talk_News             NaN        2        11
#
#    favorites                                               text  geo  \
# 0          0  PRO/AH/EDR> MERS-CoV (39): Saudi Arabia (QS, R...  NaN
# 1         83  ONE YEAR AGO: Chinese biologist carrying suspe...  NaN
# 2          0  Please remind us of your lockdown of the USA d...  NaN
# 3          4  5 epidemics in recent years #Ebola #SARS #avia...  NaN
# 4          8  #breaking FBI Report: Border Agents Stopped A ...  NaN
#
#           mentions                                           hashtags  \
# 0              NaN                                                NaN
# 1              NaN                                        #SARS #MERS
# 2              NaN                        #H1N1 #pandemic #MERS #SARS
# 3  @nicolerycroft1  #Ebola #SARS #avianflu #MERS #COVID19 #reset #...
# 4              NaN  #breaking #Chinese #SARS #MERS #coronovirus #C...
#
#                     id                                          permalink
# 0  1046195432131428353  https://twitter.com/CHMMNews/status/1046195432...
# 1  1245135596617695236  https://twitter.com/chiIIum/status/12451355966...
# 2  1245134176426360832  https://twitter.com/english_longbow/status/124...
# 3  1245133270435729408  https://twitter.com/paanfo/status/124513327043...
# 4  1245132072269774856  https://twitter.com/Real_Talk_News/status/1245...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.stats import mode

# 1. Parse ngày, bỏ dayfirst nếu dữ liệu là YYYY-MM-DD
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df['day'] = df['date'].dt.date
df['year'] = df['date'].dt.year

# 2. Tính số bài đăng mỗi ngày
daily_counts = df.groupby('day').size().reset_index(name='count')
daily_counts['year'] = pd.to_datetime(daily_counts['day']).dt.year

# 3. Tính tỷ lệ mỗi năm
yearly_total = daily_counts.groupby('year')['count'].transform('sum')
daily_counts['ratio'] = daily_counts['count'] / yearly_total

# 4. Trong hàm phân lớp, loại bỏ cột 'year' để tránh nhóm áp dụng trên cột nhóm
def classify_per_year(df_year):
    # Không drop cột 'year' nữa
    q1 = df_year['ratio'].quantile(1/3)
    q2 = df_year['ratio'].quantile(2/3)

    def label_row(r):
        if r <= q1:
            return 0
        elif r <= q2:
            return 1
        else:
            return 2

    df_year = df_year.copy()
    df_year['label'] = df_year['ratio'].apply(label_row)
    return df_year

# Áp dụng, loại bỏ cột 'year' trước khi apply để tránh bị lặp cột
daily_counts_no_year = daily_counts.drop(columns=['year'])

daily_counts_labeled = (
    daily_counts_no_year
    .groupby(daily_counts['year'], group_keys=False)  # groupby dựa trên cột year gốc bên ngoài dataframe tạm
    .apply(classify_per_year)
    .reset_index(drop=True)
)

# Thêm lại cột 'year' từ cột 'day' cho chắc chắn
daily_counts_labeled['year'] = pd.to_datetime(daily_counts_labeled['day']).dt.year

# Sắp xếp lại, gán lại dataframe chính
daily_counts = daily_counts_labeled.sort_values('day').reset_index(drop=True)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
daily_counts['count_scaled'] = scaler.fit_transform(daily_counts[['count']])

# 8. Tạo chuỗi thời gian
from scipy.stats import mode

window_size = 30
horizon = 7

X, y = [], []
for i in range(len(daily_counts) - window_size - horizon):
    X.append(daily_counts['count_scaled'].values[i:i+window_size])
    future_labels = daily_counts['label'].values[i+window_size:i+window_size+horizon]

    mode_result = mode(future_labels, keepdims=True)
    if mode_result.mode.size > 0:
        y.append(mode_result.mode[0])
    else:
        y.append(future_labels[0])  # fallback

X = np.array(X)[..., np.newaxis]
y = np.array(y)

# %%
daily_counts
# Out:
#              day  count     ratio  label  year  count_scaled
# 0     2012-09-01      2  0.006349      0  2012     -0.315669
# 1     2012-09-02      7  0.022222      2  2012     -0.298671
# 2     2012-09-03      6  0.019048      2  2012     -0.302071
# 3     2012-09-04      6  0.019048      2  2012     -0.302071
# 4     2012-09-05      3  0.009524      1  2012     -0.312270
# ...          ...    ...       ...    ...   ...           ...
# 2790  2020-05-27    110  0.004360      0  2020      0.051488
# 2791  2020-05-28     93  0.003686      0  2020     -0.006305
# 2792  2020-05-29     90  0.003567      0  2020     -0.016504
# 2793  2020-05-30     80  0.003171      0  2020     -0.050500
# 2794  2020-05-31     86  0.003408      0  2020     -0.030103
#
# [2795 rows x 6 columns]

# %%
model = InformerClassifier(input_dim=1, d_model=64, n_heads=4, d_ff=128, n_layers=2, pred_len=30, n_classes=3)
accuracy, f1 = train_model(model, train_loader, num_epochs=150)
# Out:
# Epoch 1: Loss=1.1087
# Epoch 2: Loss=1.0232
# Epoch 3: Loss=0.9990
# Epoch 4: Loss=0.9916
# Epoch 5: Loss=0.9811
# Epoch 6: Loss=0.9747
# Epoch 7: Loss=0.9610
# Epoch 8: Loss=0.9648
# Epoch 9: Loss=0.9623
# Epoch 10: Loss=0.9406
# Epoch 11: Loss=0.9356
# Epoch 12: Loss=0.9315
# Epoch 13: Loss=0.9220
# Epoch 14: Loss=0.9111
# Epoch 15: Loss=0.9143
# Epoch 16: Loss=0.8993
# Epoch 17: Loss=0.8953
# Epoch 18: Loss=0.8980
# Epoch 19: Loss=0.8860
# Epoch 20: Loss=0.8793
# Epoch 21: Loss=0.8753
# Epoch 22: Loss=0.8785
# Epoch 23: Loss=0.8525
# Epoch 24: Loss=0.8435
# Epoch 25: Loss=0.8502
# Epoch 26: Loss=0.8400
# Epoch 27: Loss=0.8286
# Epoch 28: Loss=0.8303
# Epoch 29: Loss=0.8271
# Epoch 30: Loss=0.8286
# Epoch 31: Loss=0.8105
# Epoch 32: Loss=0.8010
# Epoch 33: Loss=0.8056
# Epoch 34: Loss=0.8031
# Epoch 35: Loss=0.7955
# Epoch 36: Loss=0.7703
# Epoch 37: Loss=0.7804
# Epoch 38: Loss=0.7799
# Epoch 39: Loss=0.7594
# Epoch 40: Loss=0.7907
# Epoch 41: Loss=0.7673
# Epoch 42: Loss=0.7763
# Epoch 43: Loss=0.7596
# Epoch 44: Loss=0.7559
# Epoch 45: Loss=0.7464
# Epoch 46: Loss=0.7404
# Epoch 47: Loss=0.7547
# Epoch 48: Loss=0.7300
# Epoch 49: Loss=0.7464
# Epoch 50: Loss=0.7731
# Epoch 51: Loss=0.7366
# Epoch 52: Loss=0.7424
# Epoch 53: Loss=0.7342
# Epoch 54: Loss=0.7192
# Epoch 55: Loss=0.7207
# Epoch 56: Loss=0.7174
# Epoch 57: Loss=0.7322
# Epoch 58: Loss=0.7061
# Epoch 59: Loss=0.7201
# Epoch 60: Loss=0.7061
# Epoch 61: Loss=0.7152
# Epoch 62: Loss=0.7174
# Epoch 63: Loss=0.7027
# Epoch 64: Loss=0.6976
# Epoch 65: Loss=0.7053
# Epoch 66: Loss=0.7062
# Epoch 67: Loss=0.6946
# Epoch 68: Loss=0.6986
# Epoch 69: Loss=0.6681
# Epoch 70: Loss=0.6944
# Epoch 71: Loss=0.6847
# Epoch 72: Loss=0.6769
# Epoch 73: Loss=0.7030
# Epoch 74: Loss=0.6750
# Epoch 75: Loss=0.6738
# Epoch 76: Loss=0.6780
# Epoch 77: Loss=0.7301
# Epoch 78: Loss=0.6836
# Epoch 79: Loss=0.6713
# Epoch 80: Loss=0.6963
# Epoch 81: Loss=0.6717
# Epoch 82: Loss=0.6716
# Epoch 83: Loss=0.6542
# Epoch 84: Loss=0.6524
# Epoch 85: Loss=0.6719
# Epoch 86: Loss=0.6600
# Epoch 87: Loss=0.6400
# Epoch 88: Loss=0.6372
# Epoch 89: Loss=0.6420
# Epoch 90: Loss=0.6369
# Epoch 91: Loss=0.6490
# Epoch 92: Loss=0.6529
# Epoch 93: Loss=0.6338
# Epoch 94: Loss=0.6458
# Epoch 95: Loss=0.6379
# Epoch 96: Loss=0.6608
# Epoch 97: Loss=0.6536
# Epoch 98: Loss=0.6326
# Epoch 99: Loss=0.6303
# Epoch 100: Loss=0.6436
# Epoch 101: Loss=0.6307
# Epoch 102: Loss=0.6324
# Epoch 103: Loss=0.6166
# Epoch 104: Loss=0.6175
# Epoch 105: Loss=0.6241
# Epoch 106: Loss=0.6124
# Epoch 107: Loss=0.6185
# Epoch 108: Loss=0.5993
# Epoch 109: Loss=0.6095
# Epoch 110: Loss=0.6072
# Epoch 111: Loss=0.6036
# Epoch 112: Loss=0.6094
# Epoch 113: Loss=0.6158
# Epoch 114: Loss=0.6234
# Epoch 115: Loss=0.5979
# Epoch 116: Loss=0.6155
# Epoch 117: Loss=0.5969
# Epoch 118: Loss=0.6103
# Epoch 119: Loss=0.6160
# Epoch 120: Loss=0.6070
# Epoch 121: Loss=0.6140
# Epoch 122: Loss=0.5929
# Epoch 123: Loss=0.5857
# Epoch 124: Loss=0.5810
# Epoch 125: Loss=0.5808
# Epoch 126: Loss=0.5848
# Epoch 127: Loss=0.5831
# Epoch 128: Loss=0.5749
# Epoch 129: Loss=0.5829
# Epoch 130: Loss=0.5761
# Epoch 131: Loss=0.5784
# Epoch 132: Loss=0.5783
# Epoch 133: Loss=0.5880
# Epoch 134: Loss=0.5856
# Epoch 135: Loss=0.5558
# Epoch 136: Loss=0.5634
# Epoch 137: Loss=0.5734
# Epoch 138: Loss=0.5791
# Epoch 139: Loss=0.5797
# Epoch 140: Loss=0.5779
# Epoch 141: Loss=0.5769
# Epoch 142: Loss=0.5642
# Epoch 143: Loss=0.5759
# Epoch 144: Loss=0.5599
# Epoch 145: Loss=0.5537
# Epoch 146: Loss=0.5527
# Epoch 147: Loss=0.5571
# Epoch 148: Loss=0.5570
# Epoch 149: Loss=0.5520
# Epoch 150: Loss=0.5454
#
# Final Accuracy: 0.7581
# Final F1 Score: 0.7558
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.69      0.87      0.77      1353
#            1       0.73      0.60      0.66      1187
#            2       0.89      0.79      0.84      1184
#
#     accuracy                           0.76      3724
#    macro avg       0.77      0.75      0.76      3724
# weighted avg       0.77      0.76      0.76      3724

# %%
torch.save(model.state_dict(), 'Mers_model.pt')
print("Model saved to Mers_model.pt")
# Out:
# Model saved to Mers_model.pt

# %% [markdown]
# # Zika

# %%
file_path = "2015_Zika.csv"  # <-- thay bằng tên thật trong dataset

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "tinthnhphm21022004/datalantruyenbenh",
  file_path,
)

print(df.head())
# Out:
# /tmp/ipykernel_35/1281683183.py:3: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
#                   date      username   to  replies  retweets  favorites  \
# 0  2013-12-30 23:09:37  MirSpielrein  NaN        0         0          0
# 1  2013-12-27 03:19:04    tundesline  NaN        0         0          0
# 2  2013-12-26 20:09:18   Dhemilhadey  NaN        0         0          0
# 3  2013-12-26 19:58:48       UNCUJAY  NaN        0         0          0
# 4  2013-12-26 18:07:59      Dani_Efe  NaN        1         1          2
#
#                                                 text  geo    mentions  \
# 0  El nombre lo toma del río Ébola, que está al n...  NaN         NaN
# 1  Y d carrier noo die?"@iamLumide: Guys if u r a...  NaN  @IamLumide
# 2  In which country exactly? "@iamLumide: It's no...  NaN  @IamLumide
# 3  Where In Africa? "@iamLumide: It's not a fucki...  NaN  @IamLumide
# 4  Calor , Marginalidad , Pobreza , Droga, Delinc...  NaN         NaN
#
#               hashtags                  id  \
# 0          #Ciencia140  417794631691026432
# 1                  NaN  416407858792902656
# 2                  NaN  416299702230212608
# 3                  NaN  416297059688673280
# 4  #GobiernosKdeMierda  416269173321256961
#
#                                            permalink
# 0  https://twitter.com/MirSpielrein/status/417794...
# 1  https://twitter.com/tundesline/status/41640785...
# 2  https://twitter.com/Dhemilhadey/status/4162997...
# 3  https://twitter.com/UNCUJAY/status/41629705968...
# 4  https://twitter.com/Dani_Efe/status/4162691733...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.stats import mode

# 1. Parse ngày, bỏ dayfirst nếu dữ liệu là YYYY-MM-DD
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.dropna(subset=['date'])
df['day'] = df['date'].dt.date
df['year'] = df['date'].dt.year

# 2. Tính số bài đăng mỗi ngày
daily_counts = df.groupby('day').size().reset_index(name='count')
daily_counts['year'] = pd.to_datetime(daily_counts['day']).dt.year

# 3. Tính tỷ lệ mỗi năm
yearly_total = daily_counts.groupby('year')['count'].transform('sum')
daily_counts['ratio'] = daily_counts['count'] / yearly_total

# 4. Trong hàm phân lớp, loại bỏ cột 'year' để tránh nhóm áp dụng trên cột nhóm
def classify_per_year(df_year):
    # Không drop cột 'year' nữa
    q1 = df_year['ratio'].quantile(1/3)
    q2 = df_year['ratio'].quantile(2/3)

    def label_row(r):
        if r <= q1:
            return 0
        elif r <= q2:
            return 1
        else:
            return 2

    df_year = df_year.copy()
    df_year['label'] = df_year['ratio'].apply(label_row)
    return df_year

# Áp dụng, loại bỏ cột 'year' trước khi apply để tránh bị lặp cột
daily_counts_no_year = daily_counts.drop(columns=['year'])

daily_counts_labeled = (
    daily_counts_no_year
    .groupby(daily_counts['year'], group_keys=False)  # groupby dựa trên cột year gốc bên ngoài dataframe tạm
    .apply(classify_per_year)
    .reset_index(drop=True)
)

# Thêm lại cột 'year' từ cột 'day' cho chắc chắn
daily_counts_labeled['year'] = pd.to_datetime(daily_counts_labeled['day']).dt.year

# Sắp xếp lại, gán lại dataframe chính
daily_counts = daily_counts_labeled.sort_values('day').reset_index(drop=True)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
daily_counts['count_scaled'] = scaler.fit_transform(daily_counts[['count']])

# 8. Tạo chuỗi thời gian
from scipy.stats import mode

window_size = 30
horizon = 7

X, y = [], []
for i in range(len(daily_counts) - window_size - horizon):
    X.append(daily_counts['count_scaled'].values[i:i+window_size])
    future_labels = daily_counts['label'].values[i+window_size:i+window_size+horizon]

    mode_result = mode(future_labels, keepdims=True)
    if mode_result.mode.size > 0:
        y.append(mode_result.mode[0])
    else:
        y.append(future_labels[0])  # fallback

X = np.array(X)[..., np.newaxis]
y = np.array(y)

# %%
model = InformerClassifier(input_dim=1, d_model=64, n_heads=4, d_ff=128, n_layers=2, pred_len=30, n_classes=3)
accuracy, f1 = train_model(model, train_loader, num_epochs=150)
# Out:
# Epoch 1: Loss=1.1067
# Epoch 2: Loss=1.0321
# Epoch 3: Loss=1.0106
# Epoch 4: Loss=1.0041
# Epoch 5: Loss=0.9956
# Epoch 6: Loss=0.9887
# Epoch 7: Loss=0.9839
# Epoch 8: Loss=0.9785
# Epoch 9: Loss=0.9703
# Epoch 10: Loss=0.9564
# Epoch 11: Loss=0.9570
# Epoch 12: Loss=0.9499
# Epoch 13: Loss=0.9290
# Epoch 14: Loss=0.9295
# Epoch 15: Loss=0.9192
# Epoch 16: Loss=0.9041
# Epoch 17: Loss=0.9194
# Epoch 18: Loss=0.9061
# Epoch 19: Loss=0.8877
# Epoch 20: Loss=0.8763
# Epoch 21: Loss=0.8717
# Epoch 22: Loss=0.8714
# Epoch 23: Loss=0.8738
# Epoch 24: Loss=0.8743
# Epoch 25: Loss=0.8687
# Epoch 26: Loss=0.8675
# Epoch 27: Loss=0.8628
# Epoch 28: Loss=0.8552
# Epoch 29: Loss=0.8476
# Epoch 30: Loss=0.8320
# Epoch 31: Loss=0.8274
# Epoch 32: Loss=0.8444
# Epoch 33: Loss=0.8340
# Epoch 34: Loss=0.8406
# Epoch 35: Loss=0.8033
# Epoch 36: Loss=0.8285
# Epoch 37: Loss=0.8148
# Epoch 38: Loss=0.8008
# Epoch 39: Loss=0.8075
# Epoch 40: Loss=0.8059
# Epoch 41: Loss=0.7960
# Epoch 42: Loss=0.7988
# Epoch 43: Loss=0.8130
# Epoch 44: Loss=0.7993
# Epoch 45: Loss=0.7807
# Epoch 46: Loss=0.7803
# Epoch 47: Loss=0.7728
# Epoch 48: Loss=0.7640
# Epoch 49: Loss=0.7702
# Epoch 50: Loss=0.7608
# Epoch 51: Loss=0.7559
# Epoch 52: Loss=0.7534
# Epoch 53: Loss=0.7410
# Epoch 54: Loss=0.7569
# Epoch 55: Loss=0.7352
# Epoch 56: Loss=0.7290
# Epoch 57: Loss=0.7403
# Epoch 58: Loss=0.7224
# Epoch 59: Loss=0.7339
# Epoch 60: Loss=0.7373
# Epoch 61: Loss=0.7181
# Epoch 62: Loss=0.7021
# Epoch 63: Loss=0.7080
# Epoch 64: Loss=0.7058
# Epoch 65: Loss=0.6941
# Epoch 66: Loss=0.6955
# Epoch 67: Loss=0.6844
# Epoch 68: Loss=0.6743
# Epoch 69: Loss=0.6822
# Epoch 70: Loss=0.6783
# Epoch 71: Loss=0.6809
# Epoch 72: Loss=0.7033
# Epoch 73: Loss=0.6862
# Epoch 74: Loss=0.6587
# Epoch 75: Loss=0.6940
# Epoch 76: Loss=0.6986
# Epoch 77: Loss=0.7074
# Epoch 78: Loss=0.6861
# Epoch 79: Loss=0.6691
# Epoch 80: Loss=0.6863
# Epoch 81: Loss=0.6777
# Epoch 82: Loss=0.6550
# Epoch 83: Loss=0.6522
# Epoch 84: Loss=0.6627
# Epoch 85: Loss=0.6639
# Epoch 86: Loss=0.6718
# Epoch 87: Loss=0.6332
# Epoch 88: Loss=0.6375
# Epoch 89: Loss=0.6241
# Epoch 90: Loss=0.6382
# Epoch 91: Loss=0.6320
# Epoch 92: Loss=0.6509
# Epoch 93: Loss=0.6315
# Epoch 94: Loss=0.6270
# Epoch 95: Loss=0.6292
# Epoch 96: Loss=0.5982
# Epoch 97: Loss=0.6120
# Epoch 98: Loss=0.6215
# Epoch 99: Loss=0.6249
# Epoch 100: Loss=0.5985
# Epoch 101: Loss=0.6082
# Epoch 102: Loss=0.5943
# Epoch 103: Loss=0.5875
# Epoch 104: Loss=0.6016
# Epoch 105: Loss=0.6123
# Epoch 106: Loss=0.6120
# Epoch 107: Loss=0.5700
# Epoch 108: Loss=0.5831
# Epoch 109: Loss=0.5750
# Epoch 110: Loss=0.5767
# Epoch 111: Loss=0.5736
# Epoch 112: Loss=0.5936
# Epoch 113: Loss=0.5845
# Epoch 114: Loss=0.5610
# Epoch 115: Loss=0.5664
# Epoch 116: Loss=0.5841
# Epoch 117: Loss=0.5848
# Epoch 118: Loss=0.5775
# Epoch 119: Loss=0.5701
# Epoch 120: Loss=0.5625
# Epoch 121: Loss=0.5588
# Epoch 122: Loss=0.5681
# Epoch 123: Loss=0.5459
# Epoch 124: Loss=0.5465
# Epoch 125: Loss=0.5509
# Epoch 126: Loss=0.5398
# Epoch 127: Loss=0.5694
# Epoch 128: Loss=0.5715
# Epoch 129: Loss=0.5416
# Epoch 130: Loss=0.5369
# Epoch 131: Loss=0.5402
# Epoch 132: Loss=0.5487
# Epoch 133: Loss=0.5453
# Epoch 134: Loss=0.5292
# Epoch 135: Loss=0.5539
# Epoch 136: Loss=0.5335
# Epoch 137: Loss=0.5500
# Epoch 138: Loss=0.5363
# Epoch 139: Loss=0.5307
# Epoch 140: Loss=0.5604
# Epoch 141: Loss=0.5481
# Epoch 142: Loss=0.5473
# Epoch 143: Loss=0.5425
# Epoch 144: Loss=0.5485
# Epoch 145: Loss=0.5231
# Epoch 146: Loss=0.5223
# Epoch 147: Loss=0.5126
# Epoch 148: Loss=0.5400
# Epoch 149: Loss=0.5274
# Epoch 150: Loss=0.5027
#
# Final Accuracy: 0.7718
# Final F1 Score: 0.7702
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79      1353
#            1       0.73      0.63      0.68      1187
#            2       0.89      0.80      0.84      1184
#
#     accuracy                           0.77      3724
#    macro avg       0.78      0.77      0.77      3724
# weighted avg       0.78      0.77      0.77      3724

# %%
torch.save(model.state_dict(), 'Zika_model.pt')
print("Model saved to Zika_model.pt")
# Out:
# Model saved to Zika_model.pt
